# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
FOLDER_NAME = "annotated"

# !unzip "/content/drive/MyDrive/{FOLDER_NAME}.zip" -d "/content"
# Out:
# Archive:  /content/drive/MyDrive/annotated.zip
#    creating: /content/annotated/
#  extracting: /content/annotated/Experiment-159-Split Scenes-01-Image Export-01_0_0.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-01-Image Export-01_0_0_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-01-Image Export-01_2_2.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-01-Image Export-01_2_2_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-01-Image Export-01_3_3.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-01-Image Export-01_3_3_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-02-Image Export-02_1_3.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-02-Image Export-02_1_3_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-03-Image Export-03_3_3.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-03-Image Export-03_3_3_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-07-Image Export-07_1_1.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-07-Image Export-07_1_1_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-07-Image Export-07_1_3.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-07-Image Export-07_1_3_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-15-Image Export-15_1_1.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-15-Image Export-15_1_1_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-17-Image Export-17_0_1.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-17-Image Export-17_0_1_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-18-Image Export-18_0_1.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-18-Image Export-18_0_1_seg.npy
#  extracting: /content/annotated/Experiment-159-Split Scenes-35-Image Export-35_0_0.jpg
#  extracting: /content/annotated/Experiment-159-Split Scenes-35-Image Export-35_0_0_seg.npy
#  extracting: /content/annotated/experi-Scene-01-TR1-B11-Image Export-01_3_1.jpg
#  extracting: /content/annotated/experi-Scene-01-TR1-B11-Image Export-01_3_1_seg.npy
#  extracting: /content/annotated/experi-Scene-05-TR5-C12-Image Export-05_1_1.jpg
#  extracting: /content/annotated/experi-Scene-05-TR5-C12-Image Export-05_1_1_seg.npy
#  extracting: /content/annotated/experi-Scene-07-TR7-D11-Image Export-07_0_3.jpg
#  extracting: /content/annotated/experi-Scene-07-TR7-D11-Image Export-07_0_3_seg.npy
#  extracting: /content/annotated/experi-Scene-12-TR10-E11-Image Export-12_3_0.jpg
#  extracting: /content/annotated/experi-Scene-12-TR10-E11-Image Export-12_3_0_seg.npy
#  extracting: /content/annotated/experi-Scene-20-TR20-H12-Image Export-20_2_0.jpg
#  extracting: /content/annotated/experi-Scene-20-TR20-H12-Image Export-20_2_0_seg.npy
#    creating: /content/annotated/result/
#  extracting: /content/annotated/result/Experiment-159-Split Scenes-01-Image Export-01_0_0_overlay.jpg
#  extracting: /content/annotated/result/Experiment-159-Split Scenes-01-Image Export-01_2_2_overlay.jpg
#  extracting: /content/annotated/result/Experiment-159-Split Scenes-01-Image Export-01_3_3_overlay.jpg
#  extracting: /content/annotated/result/Experiment-159-Split Scenes-02-Image Export-02_1_3_overlay.jpg
#  extracting: /content/annotated/result/Experiment-159-Split Scenes-03-Image Export-03_3_3_overlay.jpg
#  extracting: /content/annotated/result/Experiment-159-Split Scenes-07-Image Export-07_1_1_overlay.jpg
#  extracting: /content/annotated/result/Experiment-159-Split Scenes-07-Image Export-07_1_3_overlay.jpg
#  extracting: /content/annotated/result/Experiment-159-Split Scenes-35-Image Export-35_0_0_overlay.jpg
#  extracting: /content/annotated/result/experi-Scene-01-TR1-B11-Image Export-01_3_1_overlay.jpg
#  extracting: /content/annotated/result/experi-Scene-05-TR5-C12-Image Export-05_1_1_overlay.jpg
#  extracting: /content/annotated/result/experi-Scene-12-TR10-E11-Image Export-12_3_0_overlay.jpg

# %%
import numpy as np
import glob
import cv2
from torch.utils.data import Dataset, random_split

file_names = glob.glob(FOLDER_NAME + "/*.jpg")

class ImageDataset(Dataset):
  def __len__(self):
    return len(file_names)

  def __getitem__(self, idx):
    img = cv2.imread(file_names[idx], 0)
    masks = np.load(file_names[idx].replace(".jpg", "_seg.npy"), allow_pickle=True).item()["masks"]
    return img, np.max(masks)

dataset = ImageDataset()

regression_dataset, test_dataset = random_split(dataset, [0.8, 0.2])

# %%
import matplotlib.pyplot as plt

img_num = 5

fig, ax = plt.subplots(nrows = img_num, ncols = 1, dpi=300)
fig.tight_layout()

for i in range(img_num):
  img, cnt = regression_dataset[i]
  ax[i].title.set_text(f"{cnt} cells")
  ax[i].axis("off")
  ax[i].imshow(img, cmap="gray");

# %%
import numpy as np

cell_cnts = np.zeros(len(regression_dataset))
intensities = np.zeros(len(regression_dataset))

for i in range(len(regression_dataset)):
  img, cnt = regression_dataset[i]
  cell_cnts[i] = cnt
  intensities[i] = np.mean(img)

A = np.vstack([intensities, np.ones(len(intensities))]).T
m, c = np.linalg.lstsq(A, cell_cnts, rcond=None)[0]
def f(x):
  return m * x + c

regression_x = np.linspace(np.min(intensities), np.max(intensities), 100)
regression_y = f(regression_x)

plt.xlabel("Intensity")
plt.ylabel("Cell count")
plt.plot(regression_x, regression_y)
plt.scatter(intensities, cell_cnts)
plt.show();

# %%
mse = np.zeros(len(test_dataset))

for i in range(len(test_dataset)):
  test_img, test_cnt = test_dataset[i]
  predicted_cnt = f(np.mean(test_img))
  mse[i] = (predicted_cnt - test_cnt) ** 2

print(f"Average deviation (test data): {np.sqrt(np.mean(mse))}")
# Out:
# Average deviation (test data): 82.80624893045382
